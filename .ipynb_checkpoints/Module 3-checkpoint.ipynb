# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
gold_data=pd.read_csv('GOLD.csv')
gold_data
# Out:
#              Date  Price   Open   High    Low    Vol. Change %   Pred  \
# 0    May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0
# 1    May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0
# 2    May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0
# 3    May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0
# 4    May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0
# ..            ...    ...    ...    ...    ...     ...      ...    ...
# 507  Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%    NaN
# 508  Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%    NaN
# 509  May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%    NaN
# 510  May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%    NaN
# 511  May 03, 2019  31341  31250  31500  31163   0.08K    0.44%    NaN
#
#             new
# 0    117.570740
# 1    295.430176
# 2    132.123714
# 3    101.298064
# 4    112.153318
# ..          ...
# 507  247.177322
# 508   52.201158
# 509  113.293305
# 510   48.365693
# 511  429.924911
#
# [512 rows x 9 columns]

# %%
gold_data.set_index('Date',inplace=True)
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %   Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0  112.153318
# ...             ...    ...    ...    ...     ...      ...    ...         ...
# Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%    NaN  247.177322
# Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%    NaN   52.201158
# May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%    NaN  113.293305
# May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%    NaN   48.365693
# May 03, 2019  31341  31250  31500  31163   0.08K    0.44%    NaN  429.924911
#
# [512 rows x 8 columns]

# %%
gold_without_nan = gold_data.dropna()
gold_without_nan
# Out:
#               Price   Open   High    Low    Vol. Change %   Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0  112.153318
# ...             ...    ...    ...    ...     ...      ...    ...         ...
# Dec 04, 2018  30964  30874  31085  30874   0.08K    0.57%  -31.0  301.615081
# Dec 05, 2018  30926  30830  30970  30825   0.04K   -0.12%   72.0  241.475101
# Dec 06, 2018  31005  31039  31196  30974  10.55K    0.26%   35.0  188.222186
# Dec 07, 2018  31440  31011  31480  30941  11.24K    1.40%  669.0  976.692705
# Dec 10, 2018  31895  31459  31966  31420  14.09K    1.45%  521.0  990.254297
#
# [411 rows x 8 columns]

# %%
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %   Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0  112.153318
# ...             ...    ...    ...    ...     ...      ...    ...         ...
# Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%    NaN  247.177322
# Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%    NaN   52.201158
# May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%    NaN  113.293305
# May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%    NaN   48.365693
# May 03, 2019  31341  31250  31500  31163   0.08K    0.44%    NaN  429.924911
#
# [512 rows x 8 columns]

# %%
y=np.array(gold_without_nan["Pred"])
x = np.array(gold_without_nan["new"])
x = x.reshape(-1,1)
y = y.reshape(-1,1)
regression_model = LinearRegression()
regression_model.fit(x, y)
y_predicted = regression_model.predict(x)
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)
print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
# Out:
# Slope: [[-0.00823083]]
# Intercept: [343.67028421]
# Root mean squared error:  73300.46132887459
# R2 score:  3.732507600850976e-05

# %%
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y_predicted, color='r')
plt.show()

# %%
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %  Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%   NaN  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44%   NaN  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   NaN  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%   NaN  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%   NaN  112.153318
# ...             ...    ...    ...    ...     ...      ...   ...         ...
# Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%   NaN  247.177322
# Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%   NaN   52.201158
# May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%   NaN  113.293305
# May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%   NaN   48.365693
# May 03, 2019  31341  31250  31500  31163   0.08K    0.44%   NaN  429.924911
#
# [512 rows x 8 columns]

# %%
pre_data = gold_data[:]
pre_data_new = pre_data["new"]
pre_data_new = pre_data_new.values.reshape(-1,1)
na_data = (regression_model.predict(pre_data_new))#getting predicted values
na_data_series = pd.Series(na_data.ravel())
sata = na_data_series.to_frame()

gold_data["Pred"] = sata.values

#df = gold_data.DataFrame(na_data_series, gold_data.index)

gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %        Pred  \
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  342.702580
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44%  341.238649
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%  342.582797
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  342.836517
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  342.747169
# ...             ...    ...    ...    ...     ...      ...         ...
# Apr 26, 2019  31868  31851  31934  31705   9.67K    0.08%  341.635810
# Apr 30, 2019  31625  31800  31824  31597   6.44K   -0.76%  343.240625
# May 01, 2019  31563  31604  31657  31503   1.55K   -0.20%  342.737786
# May 02, 2019  31203  31420  31425  31160   0.48K   -1.14%  343.272194
# May 03, 2019  31341  31250  31500  31163   0.08K    0.44%  340.131646
#
#                      new
# Date
# May 04, 2017  117.570740
# May 05, 2017  295.430176
# May 08, 2017  132.123714
# May 09, 2017  101.298064
# May 10, 2017  112.153318
# ...                  ...
# Apr 26, 2019  247.177322
# Apr 30, 2019   52.201158
# May 01, 2019  113.293305
# May 02, 2019   48.365693
# May 03, 2019  429.924911
#
# [512 rows x 8 columns]

# %%
y=np.array(gold_data["new"])
x=np.array(gold_data["Pred"])
x=x.reshape(-1,1)
y=y.reshape(-1,1)

regression_model=LinearRegression()
regression_model.fit(x,y)
y_predicted = regression_model.predict(x)


rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)


print('Slope:' ,regression_model.coef_)
print('Intercept:', regression_model.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)


plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')

plt.plot(x, y_predicted, color='r')
plt.show()
# Out:
# Slope: [[-121.49444741]]
# Intercept: [41754.03127127]
# Root mean squared error:  2.0681422785657492e-23
# R2 score:  1.0

# %%
plt.hist(gold_data['Pred'])
plt.show()

# %%
import seaborn as sns

sns.distplot(gold_data['Pred'])
plt.show()

# %%
#Task2

# %%
lt_data=pd.read_csv("Large_Cap/LT.csv")
lt_data['Date'] = pd.to_datetime(lt_data['Date'])
lt_data = lt_data.sort_values('Date')
lt_data.set_index('Date', inplace=True)
lt_data
# Out:
#            Symbol Series  Prev Close  Open Price  High Price  Low Price  \
# Date
# 2017-05-15     LT     EQ     1740.60     1748.60     1751.55    1736.50
# 2017-05-16     LT     EQ     1742.40     1747.00     1748.25    1727.55
# 2017-05-17     LT     EQ     1740.70     1743.90     1764.00    1730.50
# 2017-05-18     LT     EQ     1755.45     1739.65     1750.10    1716.40
# 2017-05-19     LT     EQ     1722.60     1729.00     1734.00    1697.55
# ...           ...    ...         ...         ...         ...        ...
# 2019-05-07     LT     EQ     1352.70     1357.40     1374.35    1350.00
# 2019-05-08     LT     EQ     1366.60     1363.90     1371.00    1355.00
# 2019-05-09     LT     EQ     1360.35     1357.00     1368.80    1337.60
# 2019-05-10     LT     EQ     1356.45     1359.65     1362.50    1345.10
# 2019-05-13     LT     EQ     1355.50     1345.00     1355.00    1312.00
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Date
# 2017-05-15     1742.00      1742.40        1743.15                 797134
# 2017-05-16     1740.60      1740.70        1736.62                1102926
# 2017-05-17     1754.30      1755.45        1749.36                1668586
# 2017-05-18     1722.10      1722.60        1725.53                1437220
# 2017-05-19     1720.05      1724.55        1718.73                1512094
# ...                ...          ...            ...                    ...
# 2019-05-07     1368.50      1366.60        1366.49                2596385
# 2019-05-08     1362.00      1360.35        1364.13                1601700
# 2019-05-09     1356.00      1356.45        1356.59                2464425
# 2019-05-10     1356.65      1355.50        1354.49                1466154
# 2019-05-13     1318.20      1317.65        1326.93                3422913
#
#                 Turnover  No. of Trades  Deliverable Qty  \
# Date
# 2017-05-15  1.389521e+09          52614           529359
# 2017-05-16  1.915365e+09          48756           674148
# 2017-05-17  2.918955e+09          77513           830692
# 2017-05-18  2.479968e+09          47602           915874
# 2017-05-19  2.598885e+09          59280           838396
# ...                  ...            ...              ...
# 2019-05-07  3.547930e+09          80814          1727865
# 2019-05-08  2.184919e+09          77662           910828
# 2019-05-09  3.343208e+09          97052          1560086
# 2019-05-10  1.985897e+09          69058           716794
# 2019-05-13  4.541968e+09         126334          1686523
#
#             % Dly Qt to Traded Qty
# Date
# 2017-05-15                   66.41
# 2017-05-16                   61.12
# 2017-05-17                   49.78
# 2017-05-18                   63.73
# 2017-05-19                   55.45
# ...                            ...
# 2019-05-07                   66.55
# 2019-05-08                   56.87
# 2019-05-09                   63.30
# 2019-05-10                   48.89
# 2019-05-13                   49.27
#
# [494 rows x 14 columns]

# %%
nifty_data = pd.read_csv('Nifty50/Nifty50.csv')
nifty_data['Date'] = pd.to_datetime(nifty_data['Date'])
nifty_data = nifty_data.sort_values('Date')
nifty_data.set_index('Date', inplace=True)
nifty_data
# Out:
#                 Open      High       Low     Close  Shares Traded  \
# Date
# 2017-05-15   9433.55   9449.25   9423.10   9445.40      145163953
# 2017-05-16   9461.00   9517.20   9456.35   9512.25      171709433
# 2017-05-17   9517.60   9532.60   9486.10   9525.75      211856040
# 2017-05-18   9453.20   9489.10   9418.10   9429.45      199340647
# 2017-05-19   9469.90   9505.75   9390.75   9427.90      259861396
# ...              ...       ...       ...       ...            ...
# 2019-05-07  11651.50  11657.05  11484.45  11497.90      337495624
# 2019-05-08  11478.70  11479.10  11346.95  11359.45      372826025
# 2019-05-09  11322.40  11357.60  11255.05  11301.80      373028059
# 2019-05-10  11314.15  11345.80  11251.05  11278.90      387323416
# 2019-05-13  11258.70  11300.20  11125.60  11148.20      357586433
#
#             Turnover (Rs. Cr)
# Date
# 2017-05-15            7790.97
# 2017-05-16            9209.89
# 2017-05-17           10726.23
# 2017-05-18           10782.46
# 2017-05-19           11544.77
# ...                       ...
# 2019-05-07           16632.84
# 2019-05-08           17440.01
# 2019-05-09           17602.86
# 2019-05-10           18085.19
# 2019-05-13           16722.91
#
# [494 rows x 6 columns]

# %%
fil_lt = lt_data[405:]
fil_nifty = nifty_data[405:]

# %%
return_lt = fil_lt['Close Price'].pct_change()
return_nifty = fil_nifty['Close'].pct_change()

# %%
plt.figure(figsize=(20,10))
return_lt.plot()
return_nifty.plot()
plt.ylabel("Daily Return of TCS and NIFTY")
plt.show()

# %%
fil_lt['pct_change'] = fil_lt['Close Price'].pct_change()
fil_nifty['pct_change'] = fil_nifty['Close'].pct_change()
# Out:
# /Users/askvyas/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/askvyas/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
x = fil_lt['pct_change'].dropna()
y = fil_nifty['pct_change'].dropna()
import pandas as pd 
import statsmodels.api as sm
myModel = sm.OLS(y,x).fit()
myModel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:             pct_change   R-squared (uncentered):                   0.174
# Model:                            OLS   Adj. R-squared (uncentered):              0.164
# Method:                 Least Squares   F-statistic:                              18.29
# Date:                Thu, 28 May 2020   Prob (F-statistic):                    4.84e-05
# Time:                        20:31:21   Log-Likelihood:                          321.49
# No. Observations:                  88   AIC:                                     -641.0
# Df Residuals:                      87   BIC:                                     -638.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# pct_change     0.2421      0.057      4.277      0.000       0.130       0.355
# ==============================================================================
# Omnibus:                        2.093   Durbin-Watson:                   1.643
# Prob(Omnibus):                  0.351   Jarque-Bera (JB):                1.479
# Skew:                          -0.070   Prob(JB):                        0.477
# Kurtosis:                       2.380   Cond. No.                         1.00
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
lt = pd.read_csv('Large_Cap/LT.csv', parse_dates=True, index_col='Date',)
nifty50 = pd.read_csv('Nifty50/Nifty50.csv', parse_dates=True, index_col='Date')

monthly_prices = pd.concat([lt['Close Price'], nifty50['Close']], axis=1)
monthly_prices.columns = ['LT', 'NIFTY50']

print(monthly_prices.head())

monthly_returns = monthly_prices.pct_change(1)
clean_monthly_returns = monthly_returns.dropna(axis=0)  
print(clean_monthly_returns.head())
# Out:
#                  LT  NIFTY50
# Date
# 2017-05-15  1742.40  9445.40
# 2017-05-16  1740.70  9512.25
# 2017-05-17  1755.45  9525.75
# 2017-05-18  1722.60  9429.45
# 2017-05-19  1724.55  9427.90
#                   LT   NIFTY50
# Date
# 2017-05-16 -0.000976  0.007078
# 2017-05-17  0.008474  0.001419
# 2017-05-18 -0.018713 -0.010109
# 2017-05-19  0.001132 -0.000164
# 2017-05-22  0.015888  0.001098

# %%
X = clean_monthly_returns['LT']
y = clean_monthly_returns['NIFTY50']

# %%
X1 = sm.add_constant(X)

# %%
model = sm.OLS(y, X1)

# %%
results = model.fit()
print(results.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                NIFTY50   R-squared:                       0.126
# Model:                            OLS   Adj. R-squared:                  0.124
# Method:                 Least Squares   F-statistic:                     70.83
# Date:                Thu, 28 May 2020   Prob (F-statistic):           4.30e-16
# Time:                        20:34:17   Log-Likelihood:                 1766.1
# No. Observations:                 493   AIC:                            -3528.
# Df Residuals:                     491   BIC:                            -3520.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0004      0.000      1.337      0.182      -0.000       0.001
# LT             0.1292      0.015      8.416      0.000       0.099       0.159
# ==============================================================================
# Omnibus:                       86.633   Durbin-Watson:                   1.851
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              725.427
# Skew:                           0.467   Prob(JB):                    2.99e-158
# Kurtosis:                       8.869   Cond. No.                         50.6
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
