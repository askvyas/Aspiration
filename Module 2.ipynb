# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
tm=pd.read_csv('week2.csv')
tm = tm.astype({ "Date":'datetime64'}) 

df=tm.set_index('Date')

# %%
df
# Out:
#             Unnamed: 0    Symbol Series  Prev Close  Open Price  High Price  \
# Date
# 2017-05-15           0  MINDTREE     EQ      510.60      507.35      515.00
# 2017-05-16           1  MINDTREE     EQ      509.45      507.00      515.85
# 2017-05-17           2  MINDTREE     EQ      511.30      507.05      519.70
# 2017-05-18           3  MINDTREE     EQ      506.35      502.00      516.75
# 2017-05-19           4  MINDTREE     EQ      492.90      491.95      502.95
# ...                ...       ...    ...         ...         ...         ...
# 2019-05-07         489  MINDTREE     EQ      981.75      982.80      985.00
# 2019-05-08         490  MINDTREE     EQ      979.95      981.00      985.00
# 2019-05-09         491  MINDTREE     EQ      980.50      979.60      983.15
# 2019-05-10         492  MINDTREE     EQ      980.45      980.40      982.90
# 2019-05-13         493  MINDTREE     EQ      975.35      973.40      983.00
#
# ...

# %%
#Task1
fig1=df.plot(y='Close Price')

# %%
df['Close Price'].diff().abs().sort_values(ascending = False)
# Out:
# Date
# 2018-10-19    164.05
# 2018-07-19     90.65
# 2018-04-20     82.25
# 2018-02-23     71.20
# 2018-10-31     64.70
#                ...
# 2018-12-20      0.05
# 2017-07-21      0.05
# 2019-05-09      0.05
# 2017-07-03      0.05
# 2017-05-15       NaN
# Name: Close Price, Length: 494, dtype: float64

# %%
#Task2
fig2=plt.stem(df.index,df.Day_Perc_Change)
# Out:
# /Users/askvyas/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.

# %%
#Task3 part 1
plt.figure(figsize=(20,10))
plt.stem(df.index,df['Total Traded Quantity'])
# Out:
# /Users/askvyas/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# <StemContainer object of 3 artists>

# %%
#Task3 part2
plt.figure(figsize=(20,10))
plt.stem(df['Day_Perc_Change'],df['Total Traded Quantity'])
plt.xlabel('Day_Perc_Change')
plt.ylabel('Total Traded Quantity')

plt.show()
plt.figure(figsize=(20,10))
plt.stem(df['Total Traded Quantity'],df['Day_Perc_Change'])
plt.xlabel('Total Traded Quantity')
plt.ylabel('Day_Perc_Change')

plt.show()
# Out:
# /Users/askvyas/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/askvyas/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:9: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   if __name__ == '__main__':

# %%
#DOCUMENTATION for Task3
#The positive peaks of Daily_Perc_Change vd Date(index) and Total Quantity Traded vs Date are looking almost similar
#This means that in the positive side when Daily_Perc_Change increase then Total Quantity Traded also increases by
#almost the same factor. We also know that Daily_perc_Change depends upon Closing Price ,
#this implies that Total Quantity Traded and Closing Price are also related indirectly

# %%
#Task4
df.Trend.value_counts().plot(kind='pie',label="")
tp=df.groupby(['Trend', 'Total Traded Quantity'])

# %%
plt.figure(figsize=(20,10))
df.groupby(['Trend'])['Total Traded Quantity'].mean().plot.bar()

# %%
plt.figure(figsize=(20,10))

df.groupby(['Trend'])['Total Traded Quantity'].mean().plot.bar()

# %%
#Task5
plt.figure(figsize=(20,10))
plt.hist(df['Day_Perc_Change'])
# Out:
# (array([  1.,   0.,   0.,   1.,   7., 129., 273.,  69.,   8.,   6.]),
#  array([-0.16774886, -0.14136145, -0.11497403, -0.08858662, -0.0621992 ,
#         -0.03581179, -0.00942437,  0.01696304,  0.04335046,  0.06973787,
#          0.09612529]),
#  <a list of 10 Patch objects>)

# %%
#Task6
#unfiltered dataframes
itc_uf=pd.read_csv('Large_Cap/ITC.csv')
cipla_uf=pd.read_csv('Large_Cap/CIPLA.csv')
reddy_uf=pd.read_csv('Large_Cap/DRREDDY.csv')
hdfc_uf=pd.read_csv('Large_Cap/HDFC.csv')
lt_uf=pd.read_csv('Large_Cap/LT.csv')

# %%
itc_f=itc_uf[itc_uf.Series=="EQ"]
cipla_f=cipla_uf[cipla_uf.Series=="EQ"]
reddy_f=reddy_uf[reddy_uf.Series=="EQ"]
hdfc_f=hdfc_uf[hdfc_uf.Series=="EQ"]
lt_f=lt_uf[lt_uf.Series=="EQ"]

# %%
itc_f
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0      ITC     EQ  15-May-2017      274.95      275.90      278.90     275.50
# 1      ITC     EQ  16-May-2017      277.95      278.50      284.30     278.00
# 2      ITC     EQ  17-May-2017      283.45      284.10      284.40     279.25
# 3      ITC     EQ  18-May-2017      281.65      278.00      281.05     277.05
# 4      ITC     EQ  19-May-2017      277.90      282.25      295.65     281.95
# ..     ...    ...          ...         ...         ...         ...        ...
# 491    ITC     EQ  07-May-2019      307.00      308.25      309.50     300.85
# 492    ITC     EQ  08-May-2019      301.90      300.00      303.40     298.65
# 493    ITC     EQ  09-May-2019      300.65      299.40      301.30     296.35
# 494    ITC     EQ  10-May-2019      299.85      300.00      300.45     296.90
# 495    ITC     EQ  13-May-2019      297.75      295.10      303.50     287.70
#
# ...

# %%
cipla_f
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0    CIPLA     EQ  15-May-2017      567.95      567.00      572.45     561.00
# 1    CIPLA     EQ  16-May-2017      569.00      566.65      570.00     564.00
# 2    CIPLA     EQ  17-May-2017      565.60      565.10      566.00     560.05
# 3    CIPLA     EQ  18-May-2017      562.35      559.30      564.95     556.80
# 4    CIPLA     EQ  19-May-2017      560.10      561.30      566.65     558.65
# ..     ...    ...          ...         ...         ...         ...        ...
# 491  CIPLA     EQ  07-May-2019      563.35      564.00      566.30     555.15
# 492  CIPLA     EQ  08-May-2019      557.95      556.00      561.40     549.00
# 493  CIPLA     EQ  09-May-2019      558.00      559.90      561.05     548.70
# 494  CIPLA     EQ  10-May-2019      557.75      557.75      562.70     551.00
# 495  CIPLA     EQ  13-May-2019      555.55      552.00      556.75     529.60
#
# ...

# %%
reddy_f
# Out:
#       Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0    DRREDDY     EQ  15-May-2017     2580.80     2600.00     2699.00
# 1    DRREDDY     EQ  16-May-2017     2675.80     2690.80     2734.00
# 2    DRREDDY     EQ  17-May-2017     2724.10     2720.00     2760.00
# 3    DRREDDY     EQ  18-May-2017     2736.90     2695.00     2719.85
# 4    DRREDDY     EQ  19-May-2017     2678.95     2694.95     2694.95
# ..       ...    ...          ...         ...         ...         ...
# 491  DRREDDY     EQ  07-May-2019     2920.60     2936.00     2952.00
# 492  DRREDDY     EQ  08-May-2019     2942.45     2943.00     2947.80
# 493  DRREDDY     EQ  09-May-2019     2900.50     2882.25     2909.30
# 494  DRREDDY     EQ  10-May-2019     2900.60     2908.00     2917.20
# 495  DRREDDY     EQ  13-May-2019     2876.40     2850.05     2859.95
#
#      Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# ...

# %%
hdfc_f
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0     HDFC     EQ  15-May-2017     1549.80     1554.50     1572.60    1554.10
# 2     HDFC     EQ  16-May-2017     1559.50     1558.00     1569.00    1554.00
# 3     HDFC     EQ  17-May-2017     1566.55     1565.50     1570.95    1549.75
# 5     HDFC     EQ  18-May-2017     1552.50     1547.00     1558.60    1526.50
# 7     HDFC     EQ  19-May-2017     1537.05     1545.00     1548.00    1515.35
# ..     ...    ...          ...         ...         ...         ...        ...
# 824   HDFC     EQ  07-May-2019     1965.45     1974.80     2009.15    1959.20
# 825   HDFC     EQ  08-May-2019     1966.30     1964.50     1964.50    1925.05
# 826   HDFC     EQ  09-May-2019     1930.75     1926.00     1931.60    1901.30
# 827   HDFC     EQ  10-May-2019     1914.60     1915.25     1956.00    1910.75
# 828   HDFC     EQ  13-May-2019     1931.70     1926.10     1984.40    1917.85
#
# ...

# %%
lt_f
# Out:
#     Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0       LT     EQ  15-May-2017     1740.60     1748.60     1751.55    1736.50
# 1       LT     EQ  16-May-2017     1742.40     1747.00     1748.25    1727.55
# 2       LT     EQ  17-May-2017     1740.70     1743.90     1764.00    1730.50
# 3       LT     EQ  18-May-2017     1755.45     1739.65     1750.10    1716.40
# 4       LT     EQ  19-May-2017     1722.60     1729.00     1734.00    1697.55
# ..     ...    ...          ...         ...         ...         ...        ...
# 489     LT     EQ  07-May-2019     1352.70     1357.40     1374.35    1350.00
# 490     LT     EQ  08-May-2019     1366.60     1363.90     1371.00    1355.00
# 491     LT     EQ  09-May-2019     1360.35     1357.00     1368.80    1337.60
# 492     LT     EQ  10-May-2019     1356.45     1359.65     1362.50    1345.10
# 493     LT     EQ  13-May-2019     1355.50     1345.00     1355.00    1312.00
#
# ...

# %%
columns = ['ITC','CIPLA','DRREDDY','HDFC','LT']
close_prices_dataFrame = pd.DataFrame(columns = columns)
close_prices_dataFrame['ITC'] = itc_f['Close Price']
close_prices_dataFrame['CIPLA'] = cipla_f['Close Price']
close_prices_dataFrame['DRREDDY'] = reddy_f['Close Price']
close_prices_dataFrame['HDFC'] = hdfc_f['Close Price']
close_prices_dataFrame['LT'] = lt_f['Close Price']
close_prices_dataFrame.dropna()
# Out:
#         ITC   CIPLA  DRREDDY     HDFC       LT
# 0    277.95  569.00  2675.80  1559.50  1742.40
# 2    281.65  562.35  2736.90  1566.55  1755.45
# 3    277.90  560.10  2678.95  1552.50  1722.60
# 5    303.60  563.10  2608.70  1537.05  1751.95
# 7    299.90  519.65  2516.80  1520.60  1684.45
# ..      ...     ...      ...      ...      ...
# 484  306.45  558.55  2859.40  1930.60  1358.20
# 486  304.55  567.95  2892.25  1929.55  1358.75
# 488  305.00  565.60  2919.90  1914.55  1352.70
# 490  307.00  563.35  2920.60  1875.10  1360.35
# 492  300.65  558.00  2900.50  1853.00  1355.50
#
# [250 rows x 5 columns]

# %%
pct_change_dataFrame = close_prices_dataFrame.pct_change().fillna(0)
pct_change_dataFrame.dropna()
# Out:
#           ITC     CIPLA   DRREDDY      HDFC        LT
# 0    0.000000  0.000000  0.000000  0.000000  0.000000
# 1    0.019788 -0.005975  0.018051  0.000000 -0.000976
# 2   -0.006350 -0.005746  0.004699  0.004521  0.008474
# 3   -0.013314 -0.004001 -0.021174 -0.008969 -0.018713
# 4    0.029867  0.008659 -0.008399  0.000000  0.001132
# ..        ...       ...       ...       ...       ...
# 491 -0.016612 -0.009586  0.007481  0.000000 -0.002867
# 492 -0.004140  0.000090 -0.014257 -0.011786 -0.000700
# 493 -0.002661 -0.000448  0.000034  0.000000 -0.027923
# 494 -0.007004 -0.003944 -0.008343 -0.018241  0.000000
# 495 -0.028380 -0.015930 -0.025605  0.000000  0.000000
#
# [494 rows x 5 columns]

# %%
sns.pairplot(pct_change_dataFrame)

# %%
#Task7
rolling_avg_lt = pct_change_dataFrame['LT'].rolling(7).mean()
rolling_avg_lt
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#          ...
# 491   -0.000161
# 492    0.000754
# 493   -0.004316
# 494   -0.004826
# 495   -0.003684
# Name: LT, Length: 494, dtype: float64

# %%
stand_lt = rolling_avg_lt.fillna(0).std()
stand_lt
# Out:
# 0.007172130590486991

# %%
crrDate = pd.to_datetime(lt_f['Date'])
crrDate = crrDate.tolist()


plt.figure(figsize=(20,10))
plt.plot(crrDate,rolling_avg_lt.fillna(0).tolist())

# %%
#Task8
nif_load = pd.read_csv('NIFTY50/NIFTY50.csv')
nif_load
# Out:
#             Date      Open      High       Low     Close  Shares Traded  \
# 0    15-May-2017   9433.55   9449.25   9423.10   9445.40      145163953
# 1    16-May-2017   9461.00   9517.20   9456.35   9512.25      171709433
# 2    17-May-2017   9517.60   9532.60   9486.10   9525.75      211856040
# 3    18-May-2017   9453.20   9489.10   9418.10   9429.45      199340647
# 4    19-May-2017   9469.90   9505.75   9390.75   9427.90      259861396
# ..           ...       ...       ...       ...       ...            ...
# 489  07-May-2019  11651.50  11657.05  11484.45  11497.90      337495624
# 490  08-May-2019  11478.70  11479.10  11346.95  11359.45      372826025
# 491  09-May-2019  11322.40  11357.60  11255.05  11301.80      373028059
# 492  10-May-2019  11314.15  11345.80  11251.05  11278.90      387323416
# 493  13-May-2019  11258.70  11300.20  11125.60  11148.20      357586433
#
#      Turnover (Rs. Cr)
# 0              7790.97
# 1              9209.89
# 2             10726.23
# ...

# %%
nif_close_price=nif_load['Close']
nif_change = nif_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
nifDate = pd.to_datetime(nif_load['Date'])
nifDate=nifDate.tolist()

plt.figure(figsize=(20,10))

hdfc_close_price=hdfc_f['Close Price']
hdfc_date=pd.to_datetime(hdfc_f['Date'])
    
hdfc_date=hdfc_date.tolist()
hdfc_change = hdfc_close_price.pct_change().fillna(0).rolling(7).mean().fillna(0)
plt.figure(figsize=(20,10))
plt.plot(hdfc_date,rolling_avg_lt.fillna(0).tolist())

plt.title("Volatility of NIFTY with respect to HDFC and LT")
plt.plot(nifDate,nif_change.tolist(),label = 'nifty')
plt.plot(crrDate,rolling_avg_lt.fillna(0).tolist(),label = 'lt')
plt.plot(hdfc_date,hdfc_change,label = 'hdfc')
plt.legend(loc='upper left')
plt.show()

# %%
#Task9 Moving Averages
plt.figure(figsize=(20,10))
plt.plot(hdfc_date,hdfc_change,label = 'tcs')
plt.legend(loc='upper left')
plt.show()

# %%
short_window = 21
long_window = 34

signals = pd.DataFrame(index=hdfc_f.index)
signals['signal'] = 0.0
signals['short_mavg'] = hdfc_f['Close Price'].rolling(window=short_window, min_periods=1,center=False).mean()


signals['long_mavg'] = hdfc_f['Close Price'].rolling(window=long_window, min_periods=1,center=False).mean()
signals['signal'][short_window:] = np.where(signals['short_mavg'][short_window:] > signals['long_mavg'][short_window:], 1.0,0.0)
signals['positions'] = signals['signal'].diff()
print(signals)
# Out:
#      signal   short_mavg    long_mavg  positions
# 0       0.0  1559.500000  1559.500000        NaN
# 2       0.0  1563.025000  1563.025000        0.0
# 3       0.0  1559.516667  1559.516667        0.0
# 5       0.0  1553.900000  1553.900000        0.0
# 7       0.0  1547.240000  1547.240000        0.0
# ..      ...          ...          ...        ...
# 824     1.0  2005.345238  1988.922059        0.0
# 825     1.0  2001.423810  1988.151471        0.0
# 826     1.0  1995.354762  1986.385294        0.0
# 827     1.0  1989.283333  1985.482353        0.0
# 828     0.0  1984.426190  1985.042647       -1.0
#
# [494 rows x 4 columns]

# %%
fig = plt.figure(figsize=(20,15))
ax1 = fig.add_subplot(111, ylabel='Price')
hdfc_f['Close Price'].plot(ax=ax1, color='black', lw=2.)
signals[['short_mavg', 'long_mavg']].plot(ax=ax1, lw=2.)


ax1.plot(signals.loc[signals.positions == 1.0].index, signals.short_mavg[signals.positions == 1.0], '^' , markersize=20,color='g')


ax1.plot(signals.loc[signals.positions == -1.0].index, signals.short_mavg[signals.positions == -1.0], 'v' , markersize=20,color='r')

plt.show()

# %%
#Task10

symbol='LT'
df = pd.read_csv('Large_Cap/LT.csv'.format(symbol), index_col='Date',
                 parse_dates=True, usecols=['Date', 'Close Price'],
                 na_values='nan')



df = df.rename(columns={'Close Price': symbol})
df.dropna(inplace=True)


sma = df.rolling(window=14).mean()
rstd = df.rolling(window=14).std()


upper_band = sma + 2 * rstd
upper_band = upper_band.rename(columns={symbol: 'upper'})
lower_band = sma - 2 * rstd
lower_band = lower_band.rename(columns={symbol: 'lower'})


df = df.join(upper_band).join(lower_band)
ax = df.plot(title='{} Price and BB'.format(symbol))
ax.fill_between(df.index, lower_band['lower'], upper_band['upper'], color='#ADCCFF', alpha=0.4)
ax.set_xlabel('Date')
ax.set_ylabel('SMA and BB')
ax.grid()
plt.show()
